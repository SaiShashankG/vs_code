# %% [markdown]
# manam main ga cheyyalsindhi... \
# `"git add ."` --- files annitini add chesthundhi \
# `"git add FILENAME"` --- okkaa file matrame add chesthundhi... \
# `"git commit -m 'yem changes chesaaavo clear ga rasko quotations lo'"` \
# `"git push"` ---- github lo save ayipoddhi

# %% [markdown]
# git add ante... edit chesina files kuda add cheyyali

# %% [markdown]
# first edit chesina tharvatha.. \
# file ni save cheyyali... \
# dhaani tharvatha "git status" type chestha.. file lo yemem changes chesavoo cheppuddhi.. \
# edit chesina files ni add cheyyali... "git add ." anni files add ayipothaayi.. \
# git commit -m "description" \
# git push
